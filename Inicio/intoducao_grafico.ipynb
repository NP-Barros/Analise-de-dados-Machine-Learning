# %%
import matplotlib.pyplot as plt

# %%
nomes = ['Rafael', 'Maria', 'Ana']
idades = [10, 20,15] 
plt.plot(nomes,idades)

# %%
# ajustar tamanho do grafico
plt.figure(figsize=(5,3))
plt.bar(nomes,idades)
#adicionando legendas
plt.xlabel('nomes')
plt.ylabel('idades')
# Out:
# Text(0, 0.5, 'idades')
